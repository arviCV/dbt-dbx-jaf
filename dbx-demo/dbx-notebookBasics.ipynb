# %%
print ("Hello World")

# %%
# %sql
select * from analytics.dbt_masdev.dim_customers

# %%
# %run
./includes/setup

# %%
print (full_name)

# %%
# %fs ls 'databricks-datasets'

# %%
dbutils.help()

# %%
files = dbutils.fs.ls('databricks-datasets')
display(files)
